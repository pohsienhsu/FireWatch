# %%
import pandas as pd
from utilities import *
pd.set_option("display.max_rows", 366)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
fires, aqi = load_data()

# %% [markdown]
# ## Number of Fires by Year
#
# Seems to roughly match the statistics from https://fas.org/sgp/crs/misc/IF10244.pdf for the year 2015

# %%
fires_by_year = fires.groupby("FIRE_YEAR")

# %%
fires_by_year.size()
# Out:
# FIRE_YEAR
# 1992    33773
# 1993    33977
# 1994    36075
# 1995    40816
# 1996    41483
# 1997    24261
# 1998    23598
# 1999    32295
# 2000    39843
# 2001    37670
# 2002    33562
# 2003    40419
# 2004    43999
# 2005    62889
# 2006    88106
# 2007    73367
# 2008    70146
# 2009    63803
# 2010    63121
# 2011    72489
# 2012    62442
# 2013    58411
# 2014    61341
# 2015    63344
# dtype: int64

# %%
# Number of acres burned by year
acres_burned_by_year = fires.groupby("FIRE_YEAR")
acres_burned_by_year['FIRE_SIZE'].sum()
# Out:
# FIRE_YEAR
# 1992    4.330941e+05
# 1993    4.017944e+05
# 1994    6.329064e+05
# 1995    5.131534e+05
# 1996    8.243400e+05
# 1997    2.771874e+05
# 1998    6.011231e+05
# 1999    3.026783e+06
# 2000    3.038503e+06
# 2001    2.139176e+06
# 2002    1.836951e+06
# 2003    1.755565e+06
# 2004    1.040198e+06
# 2005    3.944271e+06
# 2006    8.253112e+06
# 2007    7.266372e+06
# 2008    4.516456e+06
# 2009    2.546274e+06
# 2010    1.968821e+06
# 2011    6.128886e+06
# 2012    7.936838e+06
# 2013    2.888591e+06
# 2014    3.181756e+06
# 2015    6.260638e+06
# Name: FIRE_SIZE, dtype: float64

# %%
# %matplotlib notebook
acres_burned = acres_burned_by_year['FIRE_SIZE'].sum()
acres_burned.plot.line()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fires_by_year.get_group(2006)
# Out:
#               FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 30          HANGER FIRE       2006        0.1     2006-05-23  2006-05-23
# 31       DUNLEAVEY FIRE       2006        0.1     2006-05-25  2006-05-25
# 32          FIRECRACKER       2006        0.1     2006-07-04  2006-07-04
# 33           GWINS FIRE       2006        0.1     2006-07-10  2006-07-10
# 34       MILE 15.5 FIRE       2006        0.1     2006-08-07  2006-08-08
# ...                 ...        ...        ...            ...         ...
# 1200576       GOOSE EGG       2006        0.1     2006-08-06  2006-08-06
# 1200577      PITCH PINE       2006        1.5     2006-08-07  2006-08-09
# 1200578  JACKSON CANYON       2006    11765.0     2006-08-14  2006-08-29
# 1200579          WIENKE       2006        0.1     2006-08-19  2006-08-19
# 1200637        DRY DRAW       2006        0.5     2006-06-07  2006-06-07
#
#         STAT_CAUSE_DESCR STATE_NAME      COUNTY_NAME  STATE_CODE  COUNTY_CODE
# 30        Debris Burning     Alaska  Kenai Peninsula           2          122
# 31        Debris Burning     Alaska  Kenai Peninsula           2          122
# 32              Campfire     Alaska  Kenai Peninsula           2          122
# 33              Campfire     Alaska  Kenai Peninsula           2          122
# 34              Campfire     Alaska  Kenai Peninsula           2          122
# ...                  ...        ...              ...         ...          ...
# 1200576        Lightning    Wyoming          Natrona          56           25
# 1200577        Lightning    Wyoming          Natrona          56           25
# 1200578        Lightning    Wyoming          Natrona          56           25
# 1200579        Lightning    Wyoming          Natrona          56           25
# 1200637        Lightning    Wyoming          Natrona          56           25
#
# [88106 rows x 10 columns]

# %% [markdown]
# ## Investigate Stated Causes of Fires

# %%
fires_2006 = fires_by_year.get_group(2006)
fires_1998 = fires_by_year.get_group(1998)

causes_2006 = fires_2006.groupby("STAT_CAUSE_DESCR")
causes_1998 = fires_1998.groupby("STAT_CAUSE_DESCR")

# %%
causes_1998.size().sort_values(ascending=False)
# Out:
# STAT_CAUSE_DESCR
# Arson                4488
# Debris Burning       4392
# Lightning            4030
# Miscellaneous        2786
# Equipment Use        2265
# Railroad             1393
# Missing/Undefined    1200
# Campfire             1021
# Children              808
# Smoking               802
# Powerline             257
# Fireworks             107
# Structure              49
# dtype: int64

# %%
causes_2006.size().sort_values(ascending=False)
# Out:
# STAT_CAUSE_DESCR
# Debris Burning       22261
# Miscellaneous        17147
# Lightning            14172
# Arson                13074
# Equipment Use         7205
# Missing/Undefined     6214
# Smoking               2373
# Children              2317
# Campfire              2221
# Railroad               901
# Powerline              163
# Fireworks               41
# Structure               17
# dtype: int64

# %% [markdown]
# ### Top 20 state-counties with the most wildfires in 2006

# %%
# We can groupby FIPS_STATE and FIPS_CODE, but easier for humans to read if we groupby STATE, COUNTY_NAME
county_state_2006 = fires_2006.groupby(["STATE_NAME", "COUNTY_NAME"])
county_state_2006.size().sort_values(ascending=False)[:20]
# Out:
# STATE_NAME  COUNTY_NAME
# New York    Suffolk        738
# Arizona     Coconino       669
# Hawaii      Honolulu       550
# New York    Orange         381
# Minnesota   St Louis       347
# Texas       Atascosa       346
# New York    Nassau         337
# Oregon      Grant          333
# Idaho       Idaho          325
# Arizona     Mohave         318
# New York    Erie           313
# Texas       Wood           309
# California  Riverside      308
# New York    Monroe         305
# Louisiana   Beauregard     300
# Alabama     Mobile         297
# Montana     Lincoln        292
# Louisiana   St Tammany     289
# Texas       Smith          283
# California  Los Angeles    283
# dtype: int64

# %% [markdown]
# Top 10 states with the most wildfires in 2006

# %%
# We can groupby FIPS_STATE and FIPS_CODE, but easier for humans to read if we groupby STATE, COUNTY_NAME
state_2006 = fires_2006.groupby(["STATE_NAME"])
state_2006.size().sort_values(ascending=False)[:10]
# Out:
# STATE_NAME
# Texas             14597
# Georgia            8868
# New York           6610
# North Carolina     5010
# Florida            4723
# Alabama            3936
# California         3367
# Oregon             3036
# Louisiana          3013
# South Carolina     2836
# dtype: int64

# %%
# Top 10 states with most wildfires alltime 1992-2015
state = fires.groupby(["STATE_NAME"])
state.size().sort_values(ascending=False)[:10]
# Out:
# STATE_NAME
# Georgia           150234
# Texas             136462
# Florida            83601
# New York           80018
# California         56221
# South Carolina     53341
# Mississippi        48295
# North Carolina     47592
# Alabama            41560
# Oregon             40178
# dtype: int64

# %% [markdown]
# ### States with most acres burned based on fire size

# %%
state["FIRE_SIZE"].sum().sort_values(ascending=False)[:20]
# Out:
# STATE_NAME
# Idaho          9.591734e+06
# Texas          7.953988e+06
# Nevada         7.421757e+06
# California     6.524384e+06
# Oregon         5.792585e+06
# New Mexico     4.187921e+06
# Montana        3.628712e+06
# Washington     3.057350e+06
# Florida        3.032167e+06
# Utah           2.886954e+06
# Arizona        2.553902e+06
# Alaska         2.285323e+06
# Oklahoma       1.530667e+06
# Wyoming        1.501708e+06
# Colorado       1.208078e+06
# Minnesota      8.183956e+05
# Kansas         7.970291e+05
# Georgia        7.519269e+05
# Mississippi    7.162935e+05
# Alabama        5.979095e+05
# Name: FIRE_SIZE, dtype: float64

# %% [markdown]
# ### California acres burned by year

# %%
CA = get_fires(fires, state="California")
AL = get_fires(fires, state="Alaska")
ID = get_fires(fires, state="Idaho")

# %%
CA.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()
# Out:
# FIRE_YEAR
# 1997         14.90
# 1998      15709.70
# 1999      73361.80
# 2000      41184.70
# 2001      95824.30
# 2002     138900.50
# 2003     283607.74
# 2004      95108.67
# 2005      60821.50
# 2006     672051.94
# 2007     910144.52
# 2008    1176897.80
# 2009     356014.33
# 2010      81301.26
# 2011      84625.69
# 2012     711661.13
# 2013     544348.06
# 2014     507431.63
# 2015     675373.61
# Name: FIRE_SIZE, dtype: float64

# %%
AL.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()
# Out:
# FIRE_YEAR
# 1997          2.00
# 2004          0.50
# 2005        353.25
# 2006          5.20
# 2007          4.00
# 2008          1.20
# 2009         22.27
# 2010         14.10
# 2012          1.20
# 2013        136.10
# 2014     198275.08
# 2015    2086507.76
# Name: FIRE_SIZE, dtype: float64

# %%
ID.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()
# Out:
# FIRE_YEAR
# 1992       3196.00
# 1993        842.70
# 1994      11735.00
# 1995       1545.60
# 1996      27623.10
# 1997       1432.30
# 1998       9781.60
# 1999     382231.42
# 2000     589100.98
# 2001     163844.82
# 2002      72382.15
# 2003     201862.93
# 2004      11709.78
# 2005     600871.83
# 2006     903992.13
# 2007    2068452.94
# 2008     168701.06
# 2009      23432.81
# 2010     642887.96
# 2011     232460.61
# 2012    1772657.44
# 2013     738809.00
# 2014     195085.87
# 2015     767094.21
# Name: FIRE_SIZE, dtype: float64

# %% [markdown]
# ### For 2006, group by state, county, and date

# %%
state_county_date = fires_2006.groupby(["STATE_NAME", "COUNTY_NAME", "DISCOVERY_DATE"])

# %%
state_county_date.size()
# Out:
# STATE_NAME  COUNTY_NAME  DISCOVERY_DATE
# Alabama     Autauga      2006-01-04        1
#                          2006-01-07        2
#                          2006-01-08        2
#                          2006-01-16        4
#                          2006-01-26        1
#                                           ..
# Wyoming     Weston       2006-06-11        1
#                          2006-07-06        1
#                          2006-07-12        1
#                          2006-07-30        1
#                          2006-08-08        1
# Length: 57652, dtype: int64

# %% [markdown]
# ### For 2006, list counties that had the most fires reported in a single day

# %%
state_county_date.size().sort_values(ascending=False)[:10]
# Out:
# STATE_NAME  COUNTY_NAME  DISCOVERY_DATE
# Oregon      Grant        2006-08-08        55
# New York    Orange       2006-04-12        53
# Hawaii      Honolulu     2006-07-04        47
# Oregon      Klamath      2006-08-06        42
# California  Siskiyou     2006-08-07        37
#                          2006-07-24        34
# Idaho       Idaho        2006-08-09        33
# California  Trinity      2006-08-07        30
# Louisiana   Beauregard   2006-03-26        29
# Oregon      Jackson      2006-08-06        28
# dtype: int64

# %%
fires.nlargest(10, 'FIRE_SIZE')
# Out:
#                  FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 863187           LONG DRAW       2012   558198.3     2012-07-08  2012-07-30
# 835005            HOLLOWAY       2012   461047.0     2012-08-05  2012-08-31
# 948618                I-40       2006   427696.0     2006-03-12  2006-03-19
# 434294      MURPHY COMPLEX       2007   367785.0     2007-07-21  2007-08-26
# 1103275       MILFORD FLAT       2007   357185.0     2007-07-06  2007-08-03
# 128087                RUSH       2012   315578.8     2012-08-12  2012-10-22
# 1020269     ROCKHOUSE FIRE       2011   314444.0     2011-04-09  2011-05-12
# 255      15533 BIG CREEK 2       2015   312918.3     2015-06-22  2015-09-29
# 415735          LONG BUTTE       2010   306113.0     2010-08-21  2010-09-02
# 696819    WHITEWATER-BALDY       2012   297845.0     2012-05-16  2012-07-31
#
#         STAT_CAUSE_DESCR  STATE_NAME    COUNTY_NAME  STATE_CODE  COUNTY_CODE
# 863187         Lightning      Oregon        Malheur          41           45
# 835005         Lightning      Oregon         Harney          41           25
# 948618     Miscellaneous       Texas           Gray          48          179
# 434294         Lightning       Idaho         Owyhee          16           73
# 1103275        Lightning        Utah         Beaver          49            1
# 128087         Lightning  California         Lassen           6           35
# 1020269    Miscellaneous       Texas     Jeff Davis          48          243
# 255            Lightning      Alaska  Yukon Koyukuk           2          290
# 415735         Lightning       Idaho         Elmore          16           39
# 696819         Lightning  New Mexico         Catron          35            3

# %%
get_fires(fires, 'Colorado', 'El Paso', 2012)
# Out:
#            FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 142812          COLA       2012        0.5     2012-10-20  2012-10-21
# 142813        ENSIGN       2012        0.1     2012-03-25  2012-03-25
# 142814      SUNDANCE       2012        0.1     2012-06-10  2012-06-10
# 142815     GOLD CAMP       2012        0.1     2012-01-22  2012-01-27
# 142816           315       2012        0.1     2012-08-18  2012-08-18
# 142817  WALDO CANYON       2012    18947.0     2012-06-23         NaN
# 142818          300M       2012        0.1     2012-03-19  2012-03-20
# 142819     MT HERMAN       2012        0.5     2012-09-06  2012-09-08
# 142820     LOY GULCH       2012        0.1     2012-06-19  2012-06-19
# 142821    HELEN HUNT       2012        0.1     2012-07-29  2012-07-29
# 142822          320B       2012        0.1     2012-11-21  2012-11-23
# 142823      MONUMENT       2012        0.1     2012-04-06  2012-04-06
# 142824        PISTOL       2012        1.0     2012-07-27  2012-07-28
# 142825         STUMP       2012        0.1     2012-10-23  2012-10-23
# 142826        COLA 2       2012        0.1     2012-10-20  2012-10-21
#
#        STAT_CAUSE_DESCR STATE_NAME COUNTY_NAME  STATE_CODE  COUNTY_CODE
# 142812    Miscellaneous   Colorado     El Paso           8           41
# 142813         Campfire   Colorado     El Paso           8           41
# 142814         Campfire   Colorado     El Paso           8           41
# 142815         Campfire   Colorado     El Paso           8           41
# 142816         Campfire   Colorado     El Paso           8           41
# 142817    Miscellaneous   Colorado     El Paso           8           41
# 142818         Campfire   Colorado     El Paso           8           41
# 142819    Miscellaneous   Colorado     El Paso           8           41
# 142820            Arson   Colorado     El Paso           8           41
# 142821         Campfire   Colorado     El Paso           8           41
# 142822    Miscellaneous   Colorado     El Paso           8           41
# 142823         Campfire   Colorado     El Paso           8           41
# 142824        Lightning   Colorado     El Paso           8           41
# 142825    Miscellaneous   Colorado     El Paso           8           41
# 142826    Miscellaneous   Colorado     El Paso           8           41

# %%
aqi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7243237 entries, 0 to 7243236
# Data columns (total 11 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   STATE_NAME                 object
#  1   COUNTY_NAME                object
#  2   STATE_CODE                 int64
#  3   COUNTY_CODE                int64
#  4   DATE                       datetime64[ns]
#  5   AQI                        int64
#  6   CATEGORY                   object
#  7   DEFINING_PARAMETER         object
#  8   DEFINING_SITE              object
#  9   NUMBER_OF_SITES_REPORTING  int64
#  10  YEAR                       int64
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 607.9+ MB

# %%
get_aqi(aqi, state="Colorado", county="El Paso")["AQI"].mean()
# Out:
# 49.83194523673702

# %%
get_aqi(aqi, state="Colorado", county="El Paso", year=2012)["AQI"].mean()
# Out:
# 56.86338797814208

# %%
get_aqi(aqi, state="Colorado", county="El Paso", date="2012-06-23", days_after=14)["AQI"].mean()
# Out:
# 85.53333333333333

# %%
get_aqi(aqi, state="Idaho", county="Custer", date="2012-07-27", days_after=14)["AQI"].mean()
# Out:
# 61.6

# %%
get_aqi(aqi, state="Idaho", county="Custer", year=2012)["AQI"].mean()
# Out:
# 21.155963302752294

# %%
get_fires(fires, 'California', year=2003).nlargest(10, 'FIRE_SIZE')
# Out:
#                    FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 128497         SIMI INCIDENT       2003   108204.0     2003-10-25  2003-11-11
# 107791                  OTAY       2003    47921.0     2003-10-26  2003-10-30
# 136892   SANTA CLARA COMPLEX       2003    30170.0     2003-08-25         NaN
# 111210                COYOTE       2003    19575.8     2003-07-16  2003-07-25
# 128831  LIGHTNING HONEYDEW4M       2003    13846.0     2003-09-03  2003-09-03
# 112947              MOUNTAIN       2003    10331.0     2003-10-26  2003-11-02
# 100003               VERDALE       2003     8650.0     2003-10-24  2003-10-29
# 107417              ROBLAR 2       2003     8592.0     2003-10-21  2003-10-28
# 127410                 SMOKE       2003     7790.0     2003-07-21  2003-07-28
# 86468       CHILCOOT COMPLEX       2003     5635.0     2003-07-20  2003-07-21
#
#          STAT_CAUSE_DESCR  STATE_NAME  COUNTY_NAME  STATE_CODE  COUNTY_CODE
# 128497  Missing/Undefined  California      Ventura           6          111
# 107791      Miscellaneous  California    San Diego           6           73
# 136892          Lightning  California  Santa Clara           6           85
# 111210          Lightning  California    Riverside           6           65
# 128831          Lightning  California     Humboldt           6           23
# 112947  Missing/Undefined  California    Riverside           6           65
# 100003  Missing/Undefined  California  Los Angeles           6           37
# 107417      Equipment Use  California    San Diego           6           73
# 127410          Lightning  California       Lassen           6           35
# 86468           Lightning  California       Plumas           6           63

# %%
get_aqi(aqi, state="California", county="San Diego", date="2003-10-25", days_after=14).AQI.mean()
# Out:
# 99.06666666666666

# %%
get_aqi(aqi, state="California", county="San Diego", year=2003).AQI.mean()
# Out:
# 77.59726027397261

# %%
get_fires(fires, state='New Mexico', county="Catron", date="2012-05-16")
# Out:
#                FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 696819  WHITEWATER-BALDY       2012   297845.0     2012-05-16  2012-07-31
#
#        STAT_CAUSE_DESCR  STATE_NAME COUNTY_NAME  STATE_CODE  COUNTY_CODE
# 696819        Lightning  New Mexico      Catron          35            3

# %%
get_aqi(aqi, state="New Mexico", county="Catron", date="2012-05-16", days_after=14).AQI.mean()
# Out:
# 35.25

# %%
get_aqi(aqi, state="New Mexico", county="Catron", year=2012).AQI.mean()
# Out:
# 14.53211009174312

# %%
get_fires(fires, year=2012).nlargest(10, "FIRE_SIZE")
# Out:
#                FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 863187         LONG DRAW       2012   558198.3     2012-07-08  2012-07-30
# 835005          HOLLOWAY       2012   461047.0     2012-08-05  2012-08-31
# 128087              RUSH       2012   315578.8     2012-08-12  2012-10-22
# 696819  WHITEWATER-BALDY       2012   297845.0     2012-05-16  2012-07-31
# 419032           MUSTANG       2012   275960.0     2012-07-30  2012-11-05
# 434391       KINYON ROAD       2012   210874.0     2012-07-07  2012-07-15
# 418554          HALSTEAD       2012   181948.0     2012-07-27  2012-10-24
# 835009  MILLER HOMESTEAD       2012   160801.0     2012-07-08  2012-11-16
# 604927   ROSEBUD COMPLEX       2012   152261.1     2012-08-02  2012-08-18
# 415781     TRINITY RIDGE       2012   146832.0     2012-08-03  2012-10-22
#
#        STAT_CAUSE_DESCR  STATE_NAME COUNTY_NAME  STATE_CODE  COUNTY_CODE
# 863187        Lightning      Oregon     Malheur          41           45
# 835005        Lightning      Oregon      Harney          41           25
# 128087        Lightning  California      Lassen           6           35
# 696819        Lightning  New Mexico      Catron          35            3
# 419032        Lightning       Idaho       Lemhi          16           59
# 434391        Lightning       Idaho      Owyhee          16           73
# 418554        Lightning       Idaho      Custer          16           37
# 835009        Lightning      Oregon      Harney          41           25
# 604927        Lightning     Montana     Rosebud          30           87
# 415781    Equipment Use       Idaho      Elmore          16           39

# %%
get_aqi(aqi, state_code=41, county="Baker", date="2012-07-08", days_after=21)
# Out:
#         STATE_NAME COUNTY_NAME  STATE_CODE  COUNTY_CODE       DATE  AQI  \
# 6154575     Oregon       Baker          41            1 2012-07-08   25
# 6154576     Oregon       Baker          41            1 2012-07-09   27
# 6154577     Oregon       Baker          41            1 2012-07-10   33
# 6154578     Oregon       Baker          41            1 2012-07-11   40
# 6154579     Oregon       Baker          41            1 2012-07-12   42
# 6154580     Oregon       Baker          41            1 2012-07-13   33
# 6154581     Oregon       Baker          41            1 2012-07-14   30
# 6154582     Oregon       Baker          41            1 2012-07-15   28
# 6154583     Oregon       Baker          41            1 2012-07-16   20
# 6154584     Oregon       Baker          41            1 2012-07-17   23
# 6154585     Oregon       Baker          41            1 2012-07-18   30
# 6154586     Oregon       Baker          41            1 2012-07-19   35
# 6154587     Oregon       Baker          41            1 2012-07-20   20
# 6154588     Oregon       Baker          41            1 2012-07-21   18
# 6154589     Oregon       Baker          41            1 2012-07-22   20
# 6154590     Oregon       Baker          41            1 2012-07-23   18
# 6154591     Oregon       Baker          41            1 2012-07-24   15
# 6154592     Oregon       Baker          41            1 2012-07-25   20
# 6154593     Oregon       Baker          41            1 2012-07-26   26
# 6154594     Oregon       Baker          41            1 2012-07-27   32
# 6154595     Oregon       Baker          41            1 2012-07-28   35
# 6154596     Oregon       Baker          41            1 2012-07-29   23
#
#         CATEGORY DEFINING_PARAMETER DEFINING_SITE  NUMBER_OF_SITES_REPORTING  \
# 6154575     Good              PM2.5   41-001-0004                          1
# 6154576     Good              PM2.5   41-001-0004                          1
# 6154577     Good              PM2.5   41-001-0004                          1
# 6154578     Good              PM2.5   41-001-0004                          1
# 6154579     Good              PM2.5   41-001-0004                          1
# 6154580     Good              PM2.5   41-001-0004                          1
# 6154581     Good              PM2.5   41-001-0004                          1
# 6154582     Good              PM2.5   41-001-0004                          1
# 6154583     Good              PM2.5   41-001-0004                          1
# 6154584     Good              PM2.5   41-001-0004                          1
# 6154585     Good              PM2.5   41-001-0004                          1
# 6154586     Good              PM2.5   41-001-0004                          1
# 6154587     Good              PM2.5   41-001-0004                          1
# 6154588     Good              PM2.5   41-001-0004                          1
# 6154589     Good              PM2.5   41-001-0004                          1
# 6154590     Good              PM2.5   41-001-0004                          1
# 6154591     Good              PM2.5   41-001-0004                          1
# 6154592     Good              PM2.5   41-001-0004                          1
# 6154593     Good              PM2.5   41-001-0004                          1
# 6154594     Good              PM2.5   41-001-0004                          1
# 6154595     Good              PM2.5   41-001-0004                          1
# 6154596     Good              PM2.5   41-001-0004                          1
#
#          YEAR
# 6154575  2012
# 6154576  2012
# 6154577  2012
# 6154578  2012
# 6154579  2012
# 6154580  2012
# 6154581  2012
# 6154582  2012
# 6154583  2012
# 6154584  2012
# 6154585  2012
# 6154586  2012
# 6154587  2012
# 6154588  2012
# 6154589  2012
# 6154590  2012
# 6154591  2012
# 6154592  2012
# 6154593  2012
# 6154594  2012
# 6154595  2012
# 6154596  2012

# %%
get_aqi(aqi, state_code=41, county="Baker", year=2012).AQI.mean()
# Out:
# 29.715846994535518

# %%
get_fires(fires, state="California", year=2013).nlargest(10, "FIRE_SIZE")
# Out:
#          FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 124601         RIM       2013   255858.0     2013-08-17  2013-10-24
# 101332  POWERHOUSE       2013    30274.0     2013-05-30  2013-05-30
# 114880    MOUNTAIN       2013    27531.0     2013-07-15  2013-11-25
# 88198     AMERICAN       2013    27440.0     2013-08-10  2013-10-08
# 105671       ASPEN       2013    22992.0     2013-07-22  2013-09-08
# 122655      BUTLER       2013    22445.0     2013-07-31  2013-10-30
# 114883      SILVER       2013    20292.0     2013-08-07  2013-08-21
# 129121      CORRAL       2013    12531.0     2013-08-10  2013-10-02
# 122616     BOULDER       2013    12365.0     2013-07-31  2013-10-01
# 130670        DEER       2013    11429.0     2013-08-23  2013-08-29
#
#          STAT_CAUSE_DESCR  STATE_NAME  COUNTY_NAME  STATE_CODE  COUNTY_CODE
# 124601      Miscellaneous  California     Tuolumne           6          109
# 101332      Miscellaneous  California  Los Angeles           6           37
# 114880      Equipment Use  California    Riverside           6           65
# 88198       Miscellaneous  California       Placer           6           61
# 105671          Lightning  California       Fresno           6           19
# 122655              Arson  California     Siskiyou           6           93
# 114883  Missing/Undefined  California    Riverside           6           65
# 129121          Lightning  California     Humboldt           6           23
# 122616      Miscellaneous  California     Siskiyou           6           93
# 130670      Miscellaneous  California       Tehama           6          103

# %%
get_aqi(aqi, state_code=6, county_code=109, year=2013).AQI.mean()
# Out:
# 44.51923076923077

# %%
get_aqi(aqi, state_code=6, county_code=109, date="2013-08-17", days_after=7)
# Out:
#          STATE_NAME COUNTY_NAME  STATE_CODE  COUNTY_CODE       DATE  AQI  \
# 6287798  California    Tuolumne           6          109 2013-08-17   44
# 6287799  California    Tuolumne           6          109 2013-08-18   50
# 6287800  California    Tuolumne           6          109 2013-08-19  119
# 6287801  California    Tuolumne           6          109 2013-08-20   71
# 6287802  California    Tuolumne           6          109 2013-08-21   51
# 6287803  California    Tuolumne           6          109 2013-08-22   58
# 6287804  California    Tuolumne           6          109 2013-08-23   58
# 6287805  California    Tuolumne           6          109 2013-08-24   39
#
#                                CATEGORY DEFINING_PARAMETER DEFINING_SITE  \
# 6287798                            Good              Ozone   06-109-0005
# 6287799                            Good              Ozone   06-109-0005
# 6287800  Unhealthy for Sensitive Groups              Ozone   06-109-0005
# 6287801                        Moderate              Ozone   06-109-0005
# 6287802                        Moderate              Ozone   06-109-0005
# 6287803                        Moderate              Ozone   06-109-0005
# 6287804                        Moderate              Ozone   06-109-0005
# 6287805                            Good              Ozone   06-109-0005
#
#          NUMBER_OF_SITES_REPORTING  YEAR
# 6287798                          1  2013
# 6287799                          1  2013
# 6287800                          1  2013
# 6287801                          1  2013
# 6287802                          1  2013
# 6287803                          1  2013
# 6287804                          1  2013
# 6287805                          1  2013

# %%
compare_aqi_with_year(aqi, state_code=6, county_code=109, date="2013-08-17", days_after=14)
# Out:
# (53.93333333333333, 44.51923076923077)

# %%
get_fires(fires, state="California", county="Tuolumne", year=2013).nlargest(5, "FIRE_SIZE")
# Out:
#        FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 124601       RIM       2013   255858.0     2013-08-17  2013-10-24
# 124594     POWER       2013     1070.0     2013-08-05  2013-08-18
# 124613    MURPHY       2013      140.0     2013-06-02  2013-06-02
# 124610       NaN       2013       18.0     2013-06-23         NaN
# 124600      GRUB       2013       12.0     2013-03-17  2013-03-19
#
#          STAT_CAUSE_DESCR  STATE_NAME COUNTY_NAME  STATE_CODE  COUNTY_CODE
# 124601      Miscellaneous  California    Tuolumne           6          109
# 124594           Campfire  California    Tuolumne           6          109
# 124613  Missing/Undefined  California    Tuolumne           6          109
# 124610      Miscellaneous  California    Tuolumne           6          109
# 124600           Campfire  California    Tuolumne           6          109

# %%
# days = (days_before, days_after)
get_aqi_for_fire(fires, aqi, 124601, days=(0, 7))
# Out:
#          STATE_NAME COUNTY_NAME  STATE_CODE  COUNTY_CODE       DATE  AQI  \
# 6287798  California    Tuolumne           6          109 2013-08-17   44
# 6287799  California    Tuolumne           6          109 2013-08-18   50
# 6287800  California    Tuolumne           6          109 2013-08-19  119
# 6287801  California    Tuolumne           6          109 2013-08-20   71
# 6287802  California    Tuolumne           6          109 2013-08-21   51
# 6287803  California    Tuolumne           6          109 2013-08-22   58
# 6287804  California    Tuolumne           6          109 2013-08-23   58
# 6287805  California    Tuolumne           6          109 2013-08-24   39
#
#                                CATEGORY DEFINING_PARAMETER DEFINING_SITE  \
# 6287798                            Good              Ozone   06-109-0005
# 6287799                            Good              Ozone   06-109-0005
# 6287800  Unhealthy for Sensitive Groups              Ozone   06-109-0005
# 6287801                        Moderate              Ozone   06-109-0005
# 6287802                        Moderate              Ozone   06-109-0005
# 6287803                        Moderate              Ozone   06-109-0005
# 6287804                        Moderate              Ozone   06-109-0005
# 6287805                            Good              Ozone   06-109-0005
#
#          NUMBER_OF_SITES_REPORTING  YEAR
# 6287798                          1  2013
# 6287799                          1  2013
# 6287800                          1  2013
# 6287801                          1  2013
# 6287802                          1  2013
# 6287803                          1  2013
# 6287804                          1  2013
# 6287805                          1  2013

# %%
# Get the average AQI value from the week of the fire and the average AQI for that year
compare_aqi_for_fire(fires, aqi, 124601, days=(0, 7))
# Out:
# (61.25, 44.51923076923077)

# %%
# Get the average AQI value from the 2 weeks since fire was discovered and the average AQI for that year
compare_aqi_for_fire(fires, aqi, 124601, days=(0, 14))
# Out:
# (53.93333333333333, 44.51923076923077)

# %%
# Get the average AQI value from the 3 weeks since fire was discovered and the average AQI for that year
compare_aqi_for_fire(fires, aqi, 124601, days=(0, 21))
# Out:
# (51.13636363636363, 44.51923076923077)

# %%
# Get 500 largest fires
largest_fires = fires.nlargest(100, "FIRE_SIZE")

# %%
# Return some stats on AQI difference between the AQI of the two weeks since the fire was discovered vs. the baseline yearly AQI avg
result = largest_fires.apply(lambda row: get_aqi_change(aqi, row, (0, 14)), axis=1)

# %%
result = result[pd.notnull(result)]
result.describe()
# Out:
# count    65.000000
# mean      1.019781
# std       1.341936
# min      -0.300356
# 25%       0.211461
# 50%       0.447458
# 75%       1.187408
# max       4.509029
# dtype: float64

# %%
get_aqi_for_fire(fires, aqi, 124601, days=(0, 7))
# Out:
#          Unnamed: 0  STATE_NAME COUNTY_NAME  STATE_CODE  COUNTY_CODE  \
# 6287798     6291848  California    Tuolumne           6          109
# 6287799     6291849  California    Tuolumne           6          109
# 6287800     6291850  California    Tuolumne           6          109
# 6287801     6291851  California    Tuolumne           6          109
# 6287802     6291852  California    Tuolumne           6          109
# 6287803     6291853  California    Tuolumne           6          109
# 6287804     6291854  California    Tuolumne           6          109
# 6287805     6291855  California    Tuolumne           6          109
#
#               DATE  AQI                        CATEGORY DEFINING_PARAMETER  \
# 6287798 2013-08-17   44                            Good              Ozone
# 6287799 2013-08-18   50                            Good              Ozone
# 6287800 2013-08-19  119  Unhealthy for Sensitive Groups              Ozone
# 6287801 2013-08-20   71                        Moderate              Ozone
# 6287802 2013-08-21   51                        Moderate              Ozone
# 6287803 2013-08-22   58                        Moderate              Ozone
# 6287804 2013-08-23   58                        Moderate              Ozone
# 6287805 2013-08-24   39                            Good              Ozone
#
#         DEFINING_SITE  NUMBER_OF_SITES_REPORTING  YEAR
# 6287798   06-109-0005                          1  2013
# 6287799   06-109-0005                          1  2013
# 6287800   06-109-0005                          1  2013
# 6287801   06-109-0005                          1  2013
# 6287802   06-109-0005                          1  2013
# 6287803   06-109-0005                          1  2013
# 6287804   06-109-0005                          1  2013
# 6287805   06-109-0005                          1  2013

# %%
compare_aqi_for_fire(fires, aqi, 124601, days=(0, 21))
# Out:
# (51.13636363636363, 40.431718236203004)

# %%
fires.FIRE_SIZE.describe()
# Out:
# count    1.201230e+06
# mean     5.944972e+01
# std      1.990219e+03
# min      1.000000e-05
# 25%      1.000000e-01
# 50%      1.000000e+00
# 75%      3.900000e+00
# max      5.581983e+05
# Name: FIRE_SIZE, dtype: float64

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
fires.FIRE_SIZE.hist(ax=ax, bins=12, bottom=0)
ax.set_yscale('log')
ax.grid(False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
larger_fires = get_fires_in_range(fires, 4000, 1000000)
small_fires = get_fires_in_range(fires, 0, 3999.99)
# Sample 1000 small fires
small_fires = small_fires.sample(n=1000)

# %%
small_fires['AQI_CHANGE'] = small_fires.apply(lambda row: get_aqi_change(aqi, row, (0, 14)), axis=1)
small_fires = small_fires[pd.notnull(small_fires.AQI_CHANGE)]
small_fires
# Out:
#                    FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 274342                   NaN       2007       5.97     2007-09-27         NaN
# 67214                  LODGE       2004       0.10     2004-07-14  2004-07-14
# 743733                   NaN       2014       0.10     2014-04-12  2014-05-06
# 165256                   NaN       2005       0.10     2005-04-21         NaN
# 756159                   NaN       2007       0.10     2007-05-27  2007-05-27
# ...                      ...        ...        ...            ...         ...
# 215524                   NaN       1993       6.00     1993-05-15         NaN
# 848282               LOOKOUT       2015       0.10     2015-07-08  2015-07-08
# 105096  S DOCKERY AV  SANGER       2011       1.00     2011-07-31         NaN
# 118939              WHITMORE       2013       1.00     2013-08-22  2013-08-22
# 479361                   NaN       2015       0.75     2015-05-28  2015-05-28
#
#          STAT_CAUSE_DESCR     STATE_NAME COUNTY_NAME  STATE_CODE  COUNTY_CODE  \
# 274342          Lightning        Georgia    Muscogee          13          215
# 67214           Lightning        Arizona    Coconino           4            5
# 743733              Arson       New York    Tompkins          36          109
# 165256      Miscellaneous    Connecticut     Tolland           9           13
# 756159            Smoking       New York     Chemung          36           15
# ...                   ...            ...         ...         ...          ...
# 215524           Railroad        Florida      Citrus          12           17
# 848282          Lightning         Oregon     Douglas          41           19
# 105096          Powerline     California      Fresno           6           19
# 118939  Missing/Undefined     California      Shasta           6           89
# 479361      Miscellaneous  Massachusetts     Bristol          25            5
#
#         AQI_CHANGE
# 274342   -0.344349
# 67214     0.305656
# 743733    0.324139
# 165256   -0.122896
# 756159    0.453762
# ...            ...
# 215524    0.119879
# 848282   -0.394023
# 105096    0.159933
# 118939    0.021020
# 479361    0.051830
#
# [469 rows x 11 columns]

# %%
larger_fires['AQI_CHANGE'] = larger_fires.apply(lambda row: get_aqi_change(aqi, row, (0, 14)), axis=1)
larger_fires = larger_fires[pd.notnull(larger_fires.AQI_CHANGE)]
larger_fires
# Out:
# /home/froi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                   FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 37          140 FUNNY RIVER       2014   196722.2     2014-05-19  2014-08-31
# 228             15392 BEADY       2015     4861.3     2015-06-20  2015-09-10
# 229           15573 SULUKNA       2015    16703.6     2015-06-23  2015-09-29
# 230      15249 INNOKO RIVER       2015     8660.9     2015-06-03  2015-08-21
# 233         15359 THREE DAY       2015    97303.0     2015-06-19  2015-09-10
# ...                     ...        ...        ...            ...         ...
# 1200504           HENDERSON       2000     8390.0     2000-08-19  2000-08-21
# 1200572             SAWMILL       2006    16503.0     2006-07-18  2006-08-09
# 1200578      JACKSON CANYON       2006    11765.0     2006-08-14  2006-08-29
# 1200968    SHEEPHERDER HILL       2012    15556.0     2012-09-09  2012-10-01
# 1201067             STATION       2015     9516.0     2015-10-11  2015-10-19
#
#           STAT_CAUSE_DESCR STATE_NAME      COUNTY_NAME  STATE_CODE  \
# 37       Missing/Undefined     Alaska  Kenai Peninsula           2
# 228              Lightning     Alaska    Yukon Koyukuk           2
# 229              Lightning     Alaska    Yukon Koyukuk           2
# 230              Lightning     Alaska    Yukon Koyukuk           2
# 233              Lightning     Alaska    Yukon Koyukuk           2
# ...                    ...        ...              ...         ...
# 1200504          Lightning    Wyoming          Natrona          56
# 1200572          Lightning    Wyoming          Natrona          56
# 1200578          Lightning    Wyoming          Natrona          56
# 1200968  Missing/Undefined    Wyoming          Natrona          56
# 1201067  Missing/Undefined    Wyoming          Natrona          56
#
#          COUNTY_CODE  AQI_CHANGE
# 37               122    2.361610
# 228              290    1.187408
# 229              290    4.509029
# 230              290   -0.331625
# 233              290    1.187408
# ...              ...         ...
# 1200504           25    0.963261
# 1200572           25    0.505882
# 1200578           25    0.850980
# 1200968           25    0.269404
# 1201067           25   -0.099478
#
# [1300 rows x 11 columns]

# %%
small_fires.append(larger_fires).plot.scatter(x='FIRE_SIZE', y = 'AQI_CHANGE')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
larger_fires
# Out:
#                   FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 37          140 FUNNY RIVER       2014   196722.2     2014-05-19  2014-08-31
# 228             15392 BEADY       2015     4861.3     2015-06-20  2015-09-10
# 229           15573 SULUKNA       2015    16703.6     2015-06-23  2015-09-29
# 230      15249 INNOKO RIVER       2015     8660.9     2015-06-03  2015-08-21
# 233         15359 THREE DAY       2015    97303.0     2015-06-19  2015-09-10
# ...                     ...        ...        ...            ...         ...
# 1200504           HENDERSON       2000     8390.0     2000-08-19  2000-08-21
# 1200572             SAWMILL       2006    16503.0     2006-07-18  2006-08-09
# 1200578      JACKSON CANYON       2006    11765.0     2006-08-14  2006-08-29
# 1200968    SHEEPHERDER HILL       2012    15556.0     2012-09-09  2012-10-01
# 1201067             STATION       2015     9516.0     2015-10-11  2015-10-19
#
#           STAT_CAUSE_DESCR STATE_NAME      COUNTY_NAME  STATE_CODE  \
# 37       Missing/Undefined     Alaska  Kenai Peninsula           2
# 228              Lightning     Alaska    Yukon Koyukuk           2
# 229              Lightning     Alaska    Yukon Koyukuk           2
# 230              Lightning     Alaska    Yukon Koyukuk           2
# 233              Lightning     Alaska    Yukon Koyukuk           2
# ...                    ...        ...              ...         ...
# 1200504          Lightning    Wyoming          Natrona          56
# 1200572          Lightning    Wyoming          Natrona          56
# 1200578          Lightning    Wyoming          Natrona          56
# 1200968  Missing/Undefined    Wyoming          Natrona          56
# 1201067  Missing/Undefined    Wyoming          Natrona          56
#
#          COUNTY_CODE  AQI_CHANGE
# 37               122    2.361610
# 228              290    1.187408
# 229              290    4.509029
# 230              290   -0.331625
# 233              290    1.187408
# ...              ...         ...
# 1200504           25    0.963261
# 1200572           25    0.505882
# 1200578           25    0.850980
# 1200968           25    0.269404
# 1201067           25   -0.099478
#
# [1300 rows x 11 columns]

# %%
small_fires
# Out:
#                    FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 274342                   NaN       2007       5.97     2007-09-27         NaN
# 67214                  LODGE       2004       0.10     2004-07-14  2004-07-14
# 743733                   NaN       2014       0.10     2014-04-12  2014-05-06
# 165256                   NaN       2005       0.10     2005-04-21         NaN
# 756159                   NaN       2007       0.10     2007-05-27  2007-05-27
# ...                      ...        ...        ...            ...         ...
# 215524                   NaN       1993       6.00     1993-05-15         NaN
# 848282               LOOKOUT       2015       0.10     2015-07-08  2015-07-08
# 105096  S DOCKERY AV  SANGER       2011       1.00     2011-07-31         NaN
# 118939              WHITMORE       2013       1.00     2013-08-22  2013-08-22
# 479361                   NaN       2015       0.75     2015-05-28  2015-05-28
#
#          STAT_CAUSE_DESCR     STATE_NAME COUNTY_NAME  STATE_CODE  COUNTY_CODE  \
# 274342          Lightning        Georgia    Muscogee          13          215
# 67214           Lightning        Arizona    Coconino           4            5
# 743733              Arson       New York    Tompkins          36          109
# 165256      Miscellaneous    Connecticut     Tolland           9           13
# 756159            Smoking       New York     Chemung          36           15
# ...                   ...            ...         ...         ...          ...
# 215524           Railroad        Florida      Citrus          12           17
# 848282          Lightning         Oregon     Douglas          41           19
# 105096          Powerline     California      Fresno           6           19
# 118939  Missing/Undefined     California      Shasta           6           89
# 479361      Miscellaneous  Massachusetts     Bristol          25            5
#
#         AQI_CHANGE
# 274342   -0.344349
# 67214     0.305656
# 743733    0.324139
# 165256   -0.122896
# 756159    0.453762
# ...            ...
# 215524    0.119879
# 848282   -0.394023
# 105096    0.159933
# 118939    0.021020
# 479361    0.051830
#
# [469 rows x 11 columns]

# %%
fig, ax = plt.subplots()
fire_plots = small_fires.append(larger_fires)
ax.scatter(fire_plots['FIRE_SIZE'], fire_plots['AQI_CHANGE'])
ax.grid(False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
random_fires = fires.sample(n=2000)

# %%
random_fires['AQI_CHANGE'] = random_fires.apply(lambda row: get_aqi_change(aqi, row, (0, 14)), axis=1)
random_fires = random_fires[pd.notnull(random_fires.AQI_CHANGE)]
random_fires
# Out:
#                    FIRE_NAME  FIRE_YEAR  FIRE_SIZE DISCOVERY_DATE   CONT_DATE  \
# 408574                   NaN       2005       0.10     2005-08-21         NaN
# 1096987                TABBY       2001       0.50     2001-07-03  2001-07-04
# 248886                   NaN       2000      10.00     2000-01-08         NaN
# 1190870  308 TRANQUILITY WAY       2014       0.10     2014-03-22  2014-03-22
# 897463                   NaN       2003       3.00     2003-10-03         NaN
# ...                      ...        ...        ...            ...         ...
# 826290                  0458       2007       0.10     2007-07-12  2007-07-12
# 170009                   NaN       2000       6.00     2000-02-04         NaN
# 477983             BRAINTREE       2015       1.00     2015-07-08  2015-07-08
# 817748                 30396       2003     120.00     2003-04-02  2003-04-02
# 681378                   NaN       2004       0.25     2004-03-29         NaN
#
#           STAT_CAUSE_DESCR      STATE_NAME COUNTY_NAME  STATE_CODE  \
# 408574   Missing/Undefined          Hawaii    Honolulu          15
# 1096987          Lightning            Utah      Tooele          49
# 248886       Equipment Use         Florida  Miami-Dade          12
# 1190870     Debris Burning   West Virginia  Monongalia          54
# 897463            Children  South Carolina   Lexington          45
# ...                    ...             ...         ...         ...
# 826290       Equipment Use          Oregon   Deschutes          41
# 170009            Railroad         Florida      Marion          12
# 477983            Campfire   Massachusetts     Norfolk          25
# 817748               Arson        Oklahoma       Adair          40
# 681378            Children      New Jersey  Cumberland          34
#
#          COUNTY_CODE  AQI_CHANGE
# 408574             3   -0.300044
# 1096987           45   -0.008408
# 248886            86   -0.101701
# 1190870           61   -0.318305
# 897463            63   -0.034285
# ...              ...         ...
# 826290            17   -0.066028
# 170009            83    0.149674
# 477983            21    0.064120
# 817748             1    0.427638
# 681378            11   -0.089016
#
# [929 rows x 11 columns]

# %%
random_fires.plot.scatter(x='FIRE_SIZE', y = 'AQI_CHANGE')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
get_fires_in_range(random_fires, 0, 300).plot.scatter(x='FIRE_SIZE', y = 'AQI_CHANGE')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
random_aqis = aqi.sample(n=1000)

# %%
random_aqis
# Out:
#              STATE_NAME  COUNTY_NAME  STATE_CODE  COUNTY_CODE       DATE  AQI  \
# 5269556         Arizona     Coconino           4            5 2010-10-06   45
# 6569757       Wisconsin      Ashland          55            3 2013-10-17   25
# 4686440        Illinois       Jersey          17           83 2008-07-17  159
# 713419   South Carolina   Charleston          45           19 1994-05-24   87
# 3007112   West Virginia      Hancock          54           29 2002-03-31   41
# ...                 ...          ...         ...          ...        ...  ...
# 3100197        Illinois  Rock Island          17          161 2003-08-05   54
# 7062361       Minnesota  Saint Louis          27          137 2015-11-01   17
# 2551459     Mississippi      Jackson          28           59 2001-01-05   16
# 5878510           Texas     Rockwall          48          397 2011-10-06   50
# 356623    Massachusetts    Middlesex          25           17 1993-08-10   58
#
#           CATEGORY DEFINING_PARAMETER DEFINING_SITE  \
# 5269556       Good              Ozone   04-005-8001
# 6569757       Good              Ozone   55-003-0010
# 4686440  Unhealthy              Ozone   17-083-1001
# 713419    Moderate              Ozone   45-019-0046
# 3007112       Good               PM10   54-029-0009
# ...            ...                ...           ...
# 3100197   Moderate              PM2.5   17-161-3002
# 7062361       Good              PM2.5   27-137-7001
# 2551459       Good                SO2   28-059-0006
# 5878510       Good              Ozone   48-397-0001
# 356623    Moderate              Ozone   25-017-1801
#
#          NUMBER_OF_SITES_REPORTING  YEAR
# 5269556                          2  2010
# 6569757                          1  2013
# 4686440                          1  2008
# 713419                           3  1994
# 3007112                          8  2002
# ...                            ...   ...
# 3100197                          1  2003
# 7062361                          5  2015
# 2551459                          1  2001
# 5878510                          1  2011
# 356623                           5  1993
#
# [1000 rows x 11 columns]

# %%
def get_aqi_change2(aqi, row, days):
    date = row.DATE
    state_code = row.STATE_CODE
    county_code = row.COUNTY_CODE
    days_before = days[0]
    days_after = days[1]
    
    avg_aqi, avg_year_aqi = compare_aqi_with_year(aqi, state_code=state_code, county_code=county_code, date=date, days_before=days_before, days_after=days_after)
    if avg_aqi is None or avg_year_aqi is None:
        return None
    
    return (avg_aqi-avg_year_aqi)/avg_year_aqi

# %%
random_aqis.describe()
# Out:
#         STATE_CODE  COUNTY_CODE          AQI  NUMBER_OF_SITES_REPORTING  \
# count  1000.000000  1000.000000  1000.000000                1000.000000
# mean     29.812000    77.938000    44.770000                   2.331000
# std      16.793352    86.495825    39.499384                   2.879537
# min       1.000000     1.000000     0.000000                   1.000000
# 25%      17.000000    25.000000    27.000000                   1.000000
# 50%      30.000000    59.000000    40.000000                   1.000000
# 75%      42.000000   103.000000    52.000000                   3.000000
# max      80.000000   810.000000   911.000000                  32.000000
#
#               YEAR
# count  1000.000000
# mean   2004.386000
# std       6.755786
# min    1992.000000
# 25%    1999.000000
# 50%    2005.000000
# 75%    2010.000000
# max    2015.000000

# %%
random_aqis['AQI_CHANGE'] = random_aqis.apply(lambda row: get_aqi_change2(aqi, row, (0, 14)), axis=1)
random_aqis = random_aqis[pd.notnull(random_aqis.AQI_CHANGE)]
random_aqis
# Out:
#              STATE_NAME  COUNTY_NAME  STATE_CODE  COUNTY_CODE       DATE  AQI  \
# 5269556         Arizona     Coconino           4            5 2010-10-06   45
# 6569757       Wisconsin      Ashland          55            3 2013-10-17   25
# 4686440        Illinois       Jersey          17           83 2008-07-17  159
# 713419   South Carolina   Charleston          45           19 1994-05-24   87
# 3007112   West Virginia      Hancock          54           29 2002-03-31   41
# ...                 ...          ...         ...          ...        ...  ...
# 3100197        Illinois  Rock Island          17          161 2003-08-05   54
# 7062361       Minnesota  Saint Louis          27          137 2015-11-01   17
# 2551459     Mississippi      Jackson          28           59 2001-01-05   16
# 5878510           Texas     Rockwall          48          397 2011-10-06   50
# 356623    Massachusetts    Middlesex          25           17 1993-08-10   58
#
#           CATEGORY DEFINING_PARAMETER DEFINING_SITE  \
# 5269556       Good              Ozone   04-005-8001
# 6569757       Good              Ozone   55-003-0010
# 4686440  Unhealthy              Ozone   17-083-1001
# 713419    Moderate              Ozone   45-019-0046
# 3007112       Good               PM10   54-029-0009
# ...            ...                ...           ...
# 3100197   Moderate              PM2.5   17-161-3002
# 7062361       Good              PM2.5   27-137-7001
# 2551459       Good                SO2   28-059-0006
# 5878510       Good              Ozone   48-397-0001
# 356623    Moderate              Ozone   25-017-1801
#
#          NUMBER_OF_SITES_REPORTING  YEAR  AQI_CHANGE
# 5269556                          2  2010   -0.139866
# 6569757                          1  2013   -0.273496
# 4686440                          1  2008    0.378479
# 713419                           3  1994   -0.052914
# 3007112                          8  2002   -0.092879
# ...                            ...   ...         ...
# 3100197                          1  2003    0.285249
# 7062361                          5  2015   -0.150600
# 2551459                          1  2001   -0.415869
# 5878510                          1  2011    0.007422
# 356623                           5  1993    0.132682
#
# [1000 rows x 12 columns]

# %%
random_aqis.AQI_CHANGE.describe()
# Out:
# count    1000.000000
# mean        0.003565
# std         0.335276
# min        -1.000000
# 25%        -0.201850
# 50%        -0.040483
# 75%         0.173306
# max         3.263504
# Name: AQI_CHANGE, dtype: float64

# %%
fire_plots.AQI_CHANGE.describe()
# Out:
# count    1769.000000
# mean        0.403787
# std         0.819843
# min        -0.981804
# 25%        -0.031567
# 50%         0.203813
# 75%         0.518473
# max         4.509029
# Name: AQI_CHANGE, dtype: float64

# %%
larger_fires.AQI_CHANGE.describe()
# Out:
# count    1300.000000
# mean        0.531177
# std         0.906719
# min        -0.981804
# 25%         0.028408
# 50%         0.288922
# 75%         0.703088
# max         4.509029
# Name: AQI_CHANGE, dtype: float64

# %%
get_aqi(aqi, state_code=35, county_code=17, date="2015-04-21", days_after=7)
# Out:
#          Unnamed: 0  STATE_NAME COUNTY_NAME  STATE_CODE  COUNTY_CODE  \
# 7094462     7098512  New Mexico       Grant          35           17
# 7094463     7098513  New Mexico       Grant          35           17
# 7094464     7098514  New Mexico       Grant          35           17
# 7094465     7098515  New Mexico       Grant          35           17
# 7094466     7098516  New Mexico       Grant          35           17
# 7094467     7098517  New Mexico       Grant          35           17
# 7094468     7098518  New Mexico       Grant          35           17
# 7094469     7098519  New Mexico       Grant          35           17
#
#               DATE  AQI CATEGORY DEFINING_PARAMETER DEFINING_SITE  \
# 7094462 2015-04-21    0     Good                SO2   35-017-1003
# 7094463 2015-04-22    0     Good                SO2   35-017-1003
# 7094464 2015-04-23    0     Good                SO2   35-017-1003
# 7094465 2015-04-24    0     Good                SO2   35-017-1003
# 7094466 2015-04-25    0     Good                SO2   35-017-1003
# 7094467 2015-04-26    0     Good                SO2   35-017-1003
# 7094468 2015-04-27    0     Good                SO2   35-017-1003
# 7094469 2015-04-28    0     Good                SO2   35-017-1003
#
#          NUMBER_OF_SITES_REPORTING  YEAR
# 7094462                          1  2015
# 7094463                          1  2015
# 7094464                          1  2015
# 7094465                          1  2015
# 7094466                          1  2015
# 7094467                          1  2015
# 7094468                          1  2015
# 7094469                          1  2015
